# %%
from keras.datasets import imdb
from keras import models
from keras import layers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Download Dataset

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Vectorize

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test  = vectorize_sequences(test_data)

# %% [markdown]
# ## Preparation

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# # Model

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=([10000,])))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Learning Model

# %%
history = model.fit(
    partial_x_train,
    partial_y_train,
    epochs=10,
    batch_size=256,
    validation_split=0.3)
# Out:
# Epoch 1/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.5654 - loss: 0.7484 - val_accuracy: 0.8042 - val_loss: 0.5360
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6970 - loss: 0.6043 - val_accuracy: 0.8527 - val_loss: 0.3805
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8130 - loss: 0.4237 - val_accuracy: 0.8744 - val_loss: 0.3073
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8725 - loss: 0.3172 - val_accuracy: 0.8751 - val_loss: 0.3130
# Epoch 5/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9076 - loss: 0.2486 - val_accuracy: 0.8711 - val_loss: 0.3501
# Epoch 6/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9211 - loss: 0.2129 - val_accuracy: 0.8676 - val_loss: 0.3913
# Epoch 7/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9339 - loss: 0.1799 - val_accuracy: 0.8758 - val_loss: 0.3812
# Epoch 8/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9472 - loss: 0.1466 - val_accuracy: 0.8749 - val_loss: 0.4066
# Epoch 9/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9554 - loss: 0.1275 - val_accuracy: 0.8736 - val_loss: 0.4346
# Epoch 10/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9613 - loss: 0.1087 - val_accuracy: 0.8724 - val_loss: 0.4777

# %% [markdown]
# ## Training and validation loss

# %%
history_dict = history.history
epochs = range(1, len(history_dict['loss'])+1)
plt.plot(epochs, history_dict['loss'], 'bo', label='Training Loss')
plt.plot(epochs, history_dict['val_loss'], 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Training and validation accuracy

# %%
plt.plot(epochs, history_dict['accuracy'], 'bo', label='Training Accuracy')
plt.plot(epochs, history_dict['val_accuracy'], 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Test Accuracy

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8689 - loss: 0.4746
